# %% [markdown]
# # Gaussian Discriminant Analysis and MLE
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the calculation of **gaussian posterior probability** of GDA
# - find appropriate tuples of parameters for variout kinds of **decision boundary**

# %%
# some basic imports
import numpy as np
# %matplotlib notebook
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import math
from plot_ex1 import plot_ex1, figure

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Decision boundaries are plotted in the figure variable. You may need to refer to it after every plot

# %%
# mu: 2x1 matrix, e.g. np.array([[0,0]]).T
# Sigma: 2x2 matrix e.g. nnp.array([[1, 0], [0, 1]]).T
# phi: a number e.g 0.5

# change the value for specific decision boundary

mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 =np.array([[1,1]]).T
Sigma1 = np.array([[1, 0], [0, 1]]).T
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line', 1)
figure
# Out:
# Posterior time cost = 7.736835241317749S
# G:\大四上\机器学习\assignment\hw1_code(1)\ml2020fall_hw1\gaussian_discriminant\plot_ex1.py:46: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   fig.pcolormesh(xs, ys, decisionmap, cmap=cmap, alpha=0.8)

# %%
mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 =np.array([[1,1]]).T
Sigma1 = np.array([[1, 0], [0, 1]]).T
phi = 0.8
# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line (one side)', 2)
figure
# Out:
# Posterior time cost = 8.172555208206177S
# G:\大四上\机器学习\assignment\hw1_code(1)\ml2020fall_hw1\gaussian_discriminant\plot_ex1.py:46: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   fig.pcolormesh(xs, ys, decisionmap, cmap=cmap, alpha=0.8)

# %%
mu0 = np.array([[1,-1]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 =np.array([[1,1]]).T
Sigma1 = np.array([[0.3, 0], [0, 0.8]]).T
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Parabalic', 3)
figure
# Out:
# Posterior time cost = 8.007942199707031S
# G:\大四上\机器学习\assignment\hw1_code(1)\ml2020fall_hw1\gaussian_discriminant\plot_ex1.py:46: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   fig.pcolormesh(xs, ys, decisionmap, cmap=cmap, alpha=0.8)

# %%
mu0 = np.array([[1,1]]).T
Sigma0 = np.array([[0.2, 0], [0, 1]]).T
mu1 =np.array([[1,1]]).T
Sigma1 = np.array([[1, 0], [0, 0.6]]).T
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Hyperbola', 4)
figure
# Out:
# Posterior time cost = 5.236628532409668S
# G:\大四上\机器学习\assignment\hw1_code(1)\ml2020fall_hw1\gaussian_discriminant\plot_ex1.py:46: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   fig.pcolormesh(xs, ys, decisionmap, cmap=cmap, alpha=0.8)

# %%
mu0 = np.array([[1,1]]).T
Sigma0 = np.array([[2, 0], [0, 2]]).T
mu1 =np.array([[1,1]]).T
Sigma1 = np.array([[0.05, 0], [0, 2]]).T
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Two parallel lines.', 5)
figure
# Out:
# Posterior time cost = 13.915207386016846S
# G:\大四上\机器学习\assignment\hw1_code(1)\ml2020fall_hw1\gaussian_discriminant\plot_ex1.py:46: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   fig.pcolormesh(xs, ys, decisionmap, cmap=cmap, alpha=0.8)

# %%
mu0 = np.array([[1,1]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 =np.array([[1,1]]).T
Sigma1 = np.array([[0.1, 0], [0, 0.1]]).T
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Circle', 6)
figure
# Out:
# Posterior time cost = 6.053019285202026S
# G:\大四上\机器学习\assignment\hw1_code(1)\ml2020fall_hw1\gaussian_discriminant\plot_ex1.py:46: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   fig.pcolormesh(xs, ys, decisionmap, cmap=cmap, alpha=0.8)

# %%
mu0 = np.array([[1,1]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 =np.array([[1,1]]).T
Sigma1 = np.array([[0.1, 0], [0, 0.5]]).T
phi = 0.5
# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Ellipsoid', 7)
figure
# Out:
# Posterior time cost = 7.457663536071777S
# G:\大四上\机器学习\assignment\hw1_code(1)\ml2020fall_hw1\gaussian_discriminant\plot_ex1.py:46: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   fig.pcolormesh(xs, ys, decisionmap, cmap=cmap, alpha=0.8)

# %%
mu0 = np.array([[1,1]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 =np.array([[1,1]]).T
Sigma1 = np.array([[1, 0], [0, 1]]).T
phi = 0.5


# begin answer
# end answer


plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'No boundary', 8)
figure
# Out:
# Posterior time cost = 6.837069272994995S
# G:\大四上\机器学习\assignment\hw1_code(1)\ml2020fall_hw1\gaussian_discriminant\plot_ex1.py:46: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   fig.pcolormesh(xs, ys, decisionmap, cmap=cmap, alpha=0.8)

# %%
figure.savefig("hw1_gaussian_discriminant.png")
